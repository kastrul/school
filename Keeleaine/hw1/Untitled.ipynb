# %%
import pynini as pn

fst = (pn.a("a") | pn.a("e")) + (pn.t("a", "0").closure() | pn.t(pn.a("i").plus,
pn.a("0").star)) + pn.a("x")
fst.optimize()
# Out:
# <vector Fst at 0x7f29d81456f8>

# %%
pn.matches(fst, "ax")
# Out:
# True

# %%
pn.a("123456789")
# Out:
# <vector Fst at 0x7f29d81833e8>

# %%
a1_9 = pn.u(*"123456789").optimize()
a1_9
# Out:
# <vector Fst at 0x7f29d8145dc0>

# %%
a0_9 = (a1_9 | pn.a("0")).optimize()
a0_9
# Out:
# <vector Fst at 0x7f29d8145ed8>

# %%
f1 = (((a1_9 + pn.t("", "^ ")) | "") + a0_9).optimize()
f2 = ((a1_9 + pn.t("", "^^ ")) + ((a0_9 + pn.t("", "^ "))) + a0_9).optimize()
f = (f2 | f1).optimize()
f = pn.u(f, f + "." + a0_9.plus)

# %%
fact2 = (((a1_9 + pn.t("", "^^ ")) | "") + testf).optimize()
fact2
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-7-affb13306aab> in <module>()
# ----> 1 fact2 = (((a1_9 + pn.t("", "^^ ")) | "") + testf).optimize()
#       2 fact2
#
# NameError: name 'testf' is not defined

# %%
list(pn.randgen(f, 5).paths())

# %%
n = "100"
list((n * f).paths())

# %%
n*f

# %%
map0_9 = {"0": "", "1": "one", "2": "two", "3": "three", "4": "four", "5": "five", 
          "6": "six", "7": "seven", "8": "eight", "9": "nine"}
map10_19 = {"0": "ten", "1": "eleven", "2": "twelve", "3": "thirteen", 
            "4": "fourteen", "5": "fifteen", "6": "sixteen", "7": "seventeen",
           "8": "eighteen", "9": "nineteen"}
map20_90 = {"2": "twenty", "3": "thirty", "4": "fourty", "5": "fifty", "6": "sixty",
           "7": "seventy", "8": "eighty", "9": "ninety"}

# %%
n = "110"
list((n * f).paths())
# Out:
# [('110', '1^^ 1^ 0', <tropical Weight 0 at 0x7f29d815f990>)]

# %%
t0_9 = pn.string_map(map0_9).optimize()
t10_19 = pn.string_map(map10_19).optimize()
t20_90 = pn.string_map(map20_90).optimize()

t0 = pn.t("0", "zero")
t00 = pn.t("0^ 0","")
t10_19 = pn.t("1^ ", "") + t10_19
t20_99 = (t20_90 + pn.t("^ ", " ") + t0_9)
t1_99 = pn.u(t0, t0_9, t10_19, t20_99)

t100_999 = ((t0_9 + pn.t("^^ ", " hundred ")) + pn.u(t1_99, (pn.t("0^ ", "") + t0_9), t00))

t_all = pn.u(t1_99, t100_999)

# %%
n = "100"
list((n * f).paths())
# Out:
# [('100', '1^^ 0^ 0', <tropical Weight 0 at 0x7f29c11f9fd0>)]

# %%
list((n * f * t_all).paths())
# Out:
# [('100', 'one hundred ', <tropical Weight 0 at 0x7f29c11f9d50>),
#  ('100', 'one hundred ', <tropical Weight 0 at 0x7f29c11f9c10>)]

# %%
list(pn.randgen((t10_19 | t1_9), 5).paths())
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-168-948a6fed5b70> in <module>()
# ----> 1 list(pn.randgen((t10_19 | t1_9), 5).paths())
#
# NameError: name 't1_9' is not defined

# %%
(t20_90 + t1_9).optimize()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-11-7189fd68070b> in <module>()
# ----> 1 (t20_90 + t1_9).optimize()
#
# NameError: name 't20_90' is not defined

# %%
("123" * f * ultimate).optimize()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-12-5801a630b914> in <module>()
# ----> 1 ("123" * f * ultimate).optimize()
#
# NameError: name 'ultimate' is not defined
